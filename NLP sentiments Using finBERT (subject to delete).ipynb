# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from nltk.corpus import stopwords
from transformers import pipeline
import seaborn as sns

# %%
df = pd.read_csv('bworld_master_2021_2026.csv')
df_inf = pd.read_excel("Inflation rates from upto march.xlsx")

# %%
df = df[df['date'] >= '2021-01-01']

# %%
# Out:
#                                                headline  \
# 0     Term deposit yield ends higher as market sees ...
# 1     AIA Philippines eyes sustained profit growth a...
# 2                      Peso rises on US-Iran deal hopes
# 3                      PBB net income drops to P221.56M
# 4                         Bond yields surge on CPI data
# ...                                                 ...
# 6550     LANDBANK’s agricultural loans hit P232 billion
# 6551  Rates of T-bills, bonds to move sideways as vi...
# 6552         China caps real estate loans to curb risks
# 6553           Gov’t debt yields flat on rate cut hints
# 6554         Peso to weaken this year as trade recovers
#
#                                          headline_clean
# 0     term deposit yield ends higher market sees bsp...
# 1     aia philippines eyes sustained profit growth a...
# 2                         peso rises us-iran deal hopes
# 3                         pbb net income drops p221.56m
# 4                            bond yields surge cpi data
# ...                                                 ...
# 6550     landbank’s agricultural loans hit p232 billion
# 6551  rates t-billsbonds move sideways virus fears p...
# 6552            china caps real estate loans curb risks
# 6553              gov’t debt yields flat rate cut hints
# 6554                    peso weaken year trade recovers
#
# [6555 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18236\1381329820.py in ?()
# ----> 1 df = df.set_index('date')
#       2 df_sent = df[['sentiment']].resample('M').mean()
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5866                     if not found:
#    5867                         missing.append(col)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
#    5873             frame = self
#
# KeyError: "None of ['date'] are in the columns"

# %%
df_sent = df_sent.set_index('date')

# %%
print(df_sent['inflation'].corr(df_sent['sentiment'].rolling(3).mean()))
# Out:
# 0.41298225663635624
